# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import  *
import statsmodels.api as sm
from sklearn.decomposition import PCA
import scipy.stats

# %%
df = pd.read_csv('final.csv')

# %%
df.isnull().count()
# Out:
# Unnamed: 0                                                       61
# Age dependency ratio (% of working-age population)               61
# Agriculture, forestry, and fishing, value added (% of GDP)       61
# Agriculture, forestry, and fishing, value added (current US$)    61
# Arms imports (SIPRI trend indicator values)                      61
#                                                                  ..
# Total reserves (includes gold, current US$)                      61
# Total reserves minus gold (current US$)                          61
# Trade (% of GDP)                                                 61
# Urban population                                                 61
# Urban population (% of total population)                         61
# Length: 68, dtype: int64

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                                                       0
# Age dependency ratio (% of working-age population)               0
# Agriculture, forestry, and fishing, value added (% of GDP)       0
# Agriculture, forestry, and fishing, value added (current US$)    0
# Arms imports (SIPRI trend indicator values)                      0
#                                                                 ..
# Total reserves (includes gold, current US$)                      0
# Total reserves minus gold (current US$)                          0
# Trade (% of GDP)                                                 0
# Urban population                                                 0
# Urban population (% of total population)                         0
# Length: 68, dtype: int64

# %%
df.head(10)
# Out:
#       Unnamed: 0  Age dependency ratio (% of working-age population)  \
# 0  1960 [YR1960]                                          76.999045
# 1  1961 [YR1961]                                          78.007106
# 2  1962 [YR1962]                                          79.187531
# 3  1963 [YR1963]                                          80.304725
# 4  1964 [YR1964]                                          80.998952
# 5  1965 [YR1965]                                          81.122177
# 6  1966 [YR1966]                                          81.518179
# 7  1967 [YR1967]                                          81.306085
# 8  1968 [YR1968]                                          80.684557
# 9  1969 [YR1969]                                          79.952746
#
#    Agriculture, forestry, and fishing, value added (% of GDP)  \
# 0                                          41.312839
# 1                                          40.387402
# 2                                          38.371335
# 3                                          39.319751
# 4                                          41.187738
# 5                                          38.952143
# 6                                          40.025448
# 7                                          42.767622
# 8                                          41.633551
# 9                                          41.358343
#
#    Agriculture, forestry, and fishing, value added (current US$)  \
# 0                                       1.529810e+10
# 1                                       1.584496e+10
# 2                                       1.617792e+10
# 3                                       1.903938e+10
# 4                                       2.326295e+10
# 5                                       2.319789e+10
# 6                                       1.835786e+10
# 7                                       2.144152e+10
# 8                                       2.210136e+10
# 9                                       2.417312e+10
#
#    Arms imports (SIPRI trend indicator values)  Broad money (% of GDP)  \
# 0                                 5.440000e+08               22.071925
# 1                                 1.122000e+09               21.501873
# 2                                 3.710000e+08               21.930703
# 3                                 6.470000e+08               21.116283
# 4                                 9.200000e+08               19.806398
# 5                                 1.049000e+09               20.828616
# 6                                 9.940000e+08               20.460463
# 7                                 1.265000e+09               19.105770
# 8                                 1.655000e+09               19.761847
# 9                                 1.518000e+09               20.374808
#
#    Broad money to total reserves ratio  Changes in inventories (current US$)  \
# 0                            12.116774                          4.571559e+08
# 1                            12.659441                         -3.809357e+08
# 2                            18.031311                          1.965947e+08
# 3                            16.821091                         -3.076154e+08
# 4                            22.411741                         -2.171540e+08
# 5                            20.644809                          4.349693e+08
# 6                            15.391781                          7.380118e+08
# 7                            14.430829                         -1.807330e+08
# 8                            14.363835                         -9.723466e+08
# 9                            12.835878                         -2.097967e+07
#
#    Claims on central government, etc. (% GDP)  \
# 0                                   15.000062
# 1                                   14.725330
# 2                                   15.186626
# 3                                   14.641317
# 4                                   13.448422
# 5                                   14.093783
# 6                                   13.766973
# 7                                   12.499599
# 8                                   12.274548
# 9                                   11.585735
#
#    Consumer price index (2010 = 100)  ...  Population, total  \
# 0                           2.527487  ...        450547675.0
# 1                           2.570333  ...        459642166.0
# 2                           2.663693  ...        469077191.0
# 3                           2.742170  ...        478825602.0
# 4                           3.108394  ...        488848139.0
# 5                           3.402906  ...        499123328.0
# 6                           3.770483  ...        509631509.0
# 7                           4.262991  ...        520400577.0
# 8                           4.401002  ...        531513834.0
# 9                           4.375294  ...        543084333.0
#
#    Rural population  Rural population (% of total population)  \
# 0       369791510.0                                    82.076
# 1       376759491.0                                    81.968
# 2       383620708.0                                    81.782
# 3       390697750.0                                    81.595
# 4       397946828.0                                    81.405
# 5       405363011.0                                    81.215
# 6       412918738.0                                    81.023
# 7       420634582.0                                    80.829
# 8       428580865.0                                    80.634
# 9       436846176.0                                    80.438
#
#    Services, value added (% of GDP)  \
# 0                         38.782462
# 1                         38.325875
# 2                         39.935845
# 3                         38.095180
# 4                         36.340821
# 5                         37.450738
# 6                         36.459797
# 7                         34.609556
# 8                         35.054131
# 9                         34.305853
#
#    Taxes less subsidies on products (current US$)  \
# 0                                    2.035209e+09
# 1                                    2.303808e+09
# 2                                    2.674898e+09
# 3                                    3.294071e+09
# 4                                    3.758864e+09
# 5                                    4.352338e+09
# 6                                    3.121317e+09
# 7                                    3.251690e+09
# 8                                    3.644432e+09
# 9                                    4.076415e+09
#
#    Total reserves (includes gold, current US$)  \
# 0                                 6.745366e+08
# 1                                 6.663571e+08
# 2                                 5.127918e+08
# 3                                 6.078625e+08
# 4                                 4.991451e+08
# 5                                 6.008509e+08
# 6                                 6.096946e+08
# 7                                 6.637641e+08
# 8                                 7.303527e+08
# 9                                 9.277641e+08
#
#    Total reserves minus gold (current US$)  Trade (% of GDP)  \
# 0                              423000000.0         11.296833
# 1                              418000000.0         10.261163
# 2                              265000000.0         10.200790
# 3                              360000000.0         10.187338
# 4                              251000000.0          9.410549
# 5                              319000000.0          8.519034
# 6                              365000000.0         10.814238
# 7                              419000000.0          9.981063
# 8                              439000000.0          8.981744
# 9                              683000000.0          7.744777
#
#    Urban population  Urban population (% of total population)
# 0        80756165.0                                    17.924
# 1        82882675.0                                    18.032
# 2        85456483.0                                    18.218
# 3        88127852.0                                    18.405
# 4        90901311.0                                    18.595
# 5        93760317.0                                    18.785
# 6        96712771.0                                    18.977
# 7        99765995.0                                    19.171
# 8       102932969.0                                    19.366
# 9       106238157.0                                    19.562
#
# [10 rows x 68 columns]

# %%
df.describe()
# Out:
#        Age dependency ratio (% of working-age population)  \
# count                                          61.000000
# mean                                           68.534189
# std                                            10.239419
# min                                            48.664620
# 25%                                            59.941743
# 50%                                            71.733071
# 75%                                            76.999841
# max                                            81.518179
#
#        Agriculture, forestry, and fishing, value added (% of GDP)  \
# count                                          61.000000
# mean                                           27.692254
# std                                             8.973891
# min                                            15.970157
# 25%                                            17.814691
# 50%                                            26.896438
# 75%                                            35.269501
# max                                            42.767622
#
#        Agriculture, forestry, and fishing, value added (current US$)  \
# count                                       6.100000e+01
# mean                                        1.268410e+11
# std                                         1.287231e+11
# min                                         1.529810e+10
# 25%                                         3.519983e+10
# 50%                                         7.686453e+10
# 75%                                         1.445529e+11
# max                                         4.805041e+11
#
#        Arms imports (SIPRI trend indicator values)  Broad money (% of GDP)  \
# count                                 6.100000e+01               61.000000
# mean                                  2.000148e+09               46.532631
# std                                   1.082420e+09               21.235622
# min                                   3.710000e+08               19.105770
# 25%                                   1.184000e+09               24.466318
# 50%                                   1.807000e+09               42.816336
# 75%                                   2.769000e+09               65.548122
# max                                   5.381000e+09               88.876075
#
#        Broad money to total reserves ratio  \
# count                            61.000000
# mean                              9.037147
# std                               5.091608
# min                               3.179795
# 25%                               4.764536
# 50%                               7.054559
# 75%                              12.659441
# max                              24.018156
#
#        Changes in inventories (current US$)  \
# count                          6.100000e+01
# mean                           1.207121e+10
# std                            1.963326e+10
# min                           -1.894422e+10
# 25%                            1.965947e+08
# 50%                            2.611176e+09
# 75%                            2.145105e+10
# max                            8.046947e+10
#
#        Claims on central government, etc. (% GDP)  \
# count                                   61.000000
# mean                                    19.312167
# std                                      4.907483
# min                                     11.398051
# 25%                                     14.443072
# 50%                                     20.833257
# 75%                                     23.696514
# max                                     29.468682
#
#        Consumer price index (2010 = 100)  \
# count                          61.000000
# mean                           47.276433
# std                            52.337709
# min                             2.527487
# 25%                             7.586970
# 50%                            22.949008
# 75%                            66.043851
# max                           184.328815
#
#        Domestic credit to private sector (% of GDP)  ...  Population, total  \
# count                                     61.000000  ...       6.100000e+01
# mean                                      27.403517  ...       8.887745e+08
# std                                       14.860393  ...       2.929978e+08
# min                                        7.843133  ...       4.505477e+08
# 25%                                       14.933733  ...       6.231029e+08
# 50%                                       23.832055  ...       8.732778e+08
# 75%                                       40.067980  ...       1.147610e+09
# max                                       55.250914  ...       1.380004e+09
#
#        Rural population  Rural population (% of total population)  \
# count      6.100000e+01                                 61.000000
# mean       6.476707e+08                                 74.454361
# std        1.736535e+08                                  4.902342
# min        3.697915e+08                                 65.074000
# 25%        4.901826e+08                                 70.765000
# 50%        6.501815e+08                                 74.453000
# 75%        8.121062e+08                                 78.668000
# max        8.980241e+08                                 82.076000
#
#        Services, value added (% of GDP)  \
# count                         61.000000
# mean                          39.795285
# std                            4.960221
# min                           32.947706
# 25%                           35.521655
# 50%                           37.849668
# 75%                           44.442933
# max                           49.859559
#
#        Taxes less subsidies on products (current US$)  \
# count                                    6.100000e+01
# mean                                     5.546221e+10
# std                                      7.057469e+10
# min                                      2.035209e+09
# 25%                                      8.585605e+09
# 50%                                      2.824135e+10
# 75%                                      6.893745e+10
# max                                      2.665373e+11
#
#        Total reserves (includes gold, current US$)  \
# count                                 6.100000e+01
# mean                                  9.802227e+10
# std                                   1.497102e+11
# min                                   4.991451e+08
# 25%                                   2.324650e+09
# 50%                                   1.151174e+10
# 75%                                   1.378248e+11
# max                                   5.902274e+11
#
#        Total reserves minus gold (current US$)  Trade (% of GDP)  \
# count                             6.100000e+01         61.000000
# mean                              9.059697e+10         23.601278
# std                               1.406102e+11         15.145568
# min                               2.510000e+08          7.661769
# 25%                               1.089133e+09         12.219272
# 50%                               6.453558e+09         15.506262
# 75%                               1.319243e+11         37.503814
# max                               5.490869e+11         55.793722
#
#        Urban population  Urban population (% of total population)
# count      6.100000e+01                                 61.000000
# mean       2.411038e+08                                 25.545639
# std        1.206712e+08                                  4.902342
# min        8.075616e+07                                 17.924000
# 25%        1.329203e+08                                 21.332000
# 50%        2.230963e+08                                 25.547000
# 75%        3.355038e+08                                 29.235000
# max        4.819803e+08                                 34.926000
#
# [8 rows x 67 columns]

# %%
df.shape
# Out:
# (61, 68)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Age dependency ratio (% of working-age population)',
#        'Agriculture, forestry, and fishing, value added (% of GDP)',
#        'Agriculture, forestry, and fishing, value added (current US$)',
#        'Arms imports (SIPRI trend indicator values)', 'Broad money (% of GDP)',
#        'Broad money to total reserves ratio',
#        'Changes in inventories (current US$)',
#        'Claims on central government, etc. (% GDP)',
#        'Consumer price index (2010 = 100)',
#        'Domestic credit to private sector (% of GDP)',
#        'Domestic credit to private sector by banks (% of GDP)',
#        'Exports of goods and services (% of GDP)',
#        'Exports of goods and services (current US$)',
#        'External balance on goods and services (% of GDP)',
#        'External balance on goods and services (current US$)',
#        'Final consumption expenditure (% of GDP)',
#        'Final consumption expenditure (current US$)',
#        'Fixed telephone subscriptions',
#        'Fixed telephone subscriptions (per 100 people)', 'GDP (current US$)',
#        'GDP deflator (base year varies by country)',
#        'GDP per capita (current US$)',
#        'General government final consumption expenditure (% of GDP)',
#        'General government final consumption expenditure (current US$)',
#        'GNI (current US$)', 'Gross capital formation (% of GDP)',
#        'Gross capital formation (current US$)',
#        'Gross domestic savings (% of GDP)',
#        'Gross domestic savings (current US$)',
#        'Gross fixed capital formation (% of GDP)',
#        'Gross fixed capital formation (current US$)',
#        'Gross national expenditure (% of GDP)',
#        'Gross national expenditure (current US$)',
#        'Gross national expenditure deflator (base year varies by country)',
#        'Gross value added at basic prices (GVA) (current US$)',
#        'Households and NPISHs final consumption expenditure (% of GDP)',
#        'Households and NPISHs Final consumption expenditure (current US$)',
#        'Imports of goods and services (% of GDP)',
#        'Imports of goods and services (current US$)',
#        'Industry (including construction), value added (% of GDP)',
#        'Industry (including construction), value added (current US$)',
#        'Inflation, consumer prices (annual %)',
#        'Manufacturing, value added (% of GDP)',
#        'Manufacturing, value added (current US$)',
#        'Merchandise exports (current US$)',
#        'Merchandise imports (current US$)', 'Merchandise trade (% of GDP)',
#        'Military expenditure (% of GDP)', 'Military expenditure (current USD)',
#        'Monetary Sector credit to private sector (% GDP)',
#        'Net primary income (Net income from abroad) (current US$)',
#        'Population ages 0-14, total',
#        'Population ages 15-64 (% of total population)', 'Population, female',
#        'Population, female (% of total population)', 'Population, male',
#        'Population, male (% of total population)', 'Population, total',
#        'Rural population', 'Rural population (% of total population)',
#        'Services, value added (% of GDP)',
#        'Taxes less subsidies on products (current US$)',
#        'Total reserves (includes gold, current US$)',
#        'Total reserves minus gold (current US$)', 'Trade (% of GDP)',
#        'Urban population', 'Urban population (% of total population)'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Unnamed: 0                                                        object
# Age dependency ratio (% of working-age population)               float64
# Agriculture, forestry, and fishing, value added (% of GDP)       float64
# Agriculture, forestry, and fishing, value added (current US$)    float64
# Arms imports (SIPRI trend indicator values)                      float64
#                                                                   ...
# Total reserves (includes gold, current US$)                      float64
# Total reserves minus gold (current US$)                          float64
# Trade (% of GDP)                                                 float64
# Urban population                                                 float64
# Urban population (% of total population)                         float64
# Length: 68, dtype: object

# %%
c = df.columns

# %% [raw]
# Data Transformations:
# 1)log transform
# 2)Quantile Transform
# 3)Yeo-Johnson Transform

# %% [raw]
# Before transform

# %%
df
# Out:
#        Unnamed: 0  Age dependency ratio (% of working-age population)  \
# 0   1960 [YR1960]                                          76.999045
# 1   1961 [YR1961]                                          78.007106
# 2   1962 [YR1962]                                          79.187531
# 3   1963 [YR1963]                                          80.304725
# 4   1964 [YR1964]                                          80.998952
# ..            ...                                                ...
# 56  2016 [YR2016]                                          50.888137
# 57  2017 [YR2017]                                          50.289637
# 58  2018 [YR2018]                                          49.775167
# 59  2019 [YR2019]                                          49.245242
# 60  2020 [YR2020]                                          48.664620
#
#     Agriculture, forestry, and fishing, value added (% of GDP)  \
# 0                                           41.312839
# 1                                           40.387402
# 2                                           38.371335
# 3                                           39.319751
# 4                                           41.187738
# ..                                                ...
# 56                                          16.363801
# 57                                          16.558331
# 58                                          15.970157
# 59                                          16.677462
# 60                                          18.318988
#
#     Agriculture, forestry, and fishing, value added (current US$)  \
# 0                                        1.529810e+10
# 1                                        1.584496e+10
# 2                                        1.617792e+10
# 3                                        1.903938e+10
# 4                                        2.326295e+10
# ..                                                ...
# 56                                       3.755162e+11
# 57                                       4.390397e+11
# 58                                       4.313718e+11
# 59                                       4.787272e+11
# 60                                       4.805041e+11
#
#     Arms imports (SIPRI trend indicator values)  Broad money (% of GDP)  \
# 0                                  5.440000e+08               22.071925
# 1                                  1.122000e+09               21.501873
# 2                                  3.710000e+08               21.930703
# 3                                  6.470000e+08               21.116283
# 4                                  9.200000e+08               19.806398
# ..                                          ...                     ...
# 56                                 3.003000e+09               74.549265
# 57                                 2.909000e+09               74.144189
# 58                                 1.485000e+09               74.147695
# 59                                 3.075000e+09               76.045964
# 60                                 2.799000e+09               88.876075
#
#     Broad money to total reserves ratio  Changes in inventories (current US$)  \
# 0                             12.116774                          4.571559e+08
# 1                             12.659441                         -3.809357e+08
# 2                             18.031311                          1.965947e+08
# 3                             16.821091                         -3.076154e+08
# 4                             22.411741                         -2.171540e+08
# ..                                  ...                                   ...
# 56                             4.729837                          2.058732e+10
# 57                             4.764536                          3.686001e+10
# 58                             5.017477                          4.548057e+10
# 59                             4.709912                          2.742585e+10
# 60                             3.949673                          2.581301e+10
#
#     Claims on central government, etc. (% GDP)  \
# 0                                    15.000062
# 1                                    14.725330
# 2                                    15.186626
# 3                                    14.641317
# 4                                    13.448422
# ..                                         ...
# 56                                   25.224594
# 57                                   23.212274
# 58                                   22.107558
# 59                                   23.733819
# 60                                   29.468682
#
#     Consumer price index (2010 = 100)  ...  Population, total  \
# 0                            2.527487  ...       4.505477e+08
# 1                            2.570333  ...       4.596422e+08
# 2                            2.663693  ...       4.690772e+08
# 3                            2.742170  ...       4.788256e+08
# 4                            3.108394  ...       4.888481e+08
# ..                                ...  ...                ...
# 56                         155.182121  ...       1.324517e+09
# 57                         160.346852  ...       1.338677e+09
# 58                         166.672645  ...       1.352642e+09
# 59                         172.878328  ...       1.366418e+09
# 60                         184.328815  ...       1.380004e+09
#
#     Rural population  Rural population (% of total population)  \
# 0        369791510.0                                    82.076
# 1        376759491.0                                    81.968
# 2        383620708.0                                    81.782
# 3        390697750.0                                    81.595
# 4        397946828.0                                    81.405
# ..               ...                                       ...
# 56       885015936.0                                    66.818
# 57       888881381.0                                    66.400
# 58       892338114.0                                    65.970
# 59       895386227.0                                    65.528
# 60       898024053.0                                    65.074
#
#     Services, value added (% of GDP)  \
# 0                          38.782462
# 1                          38.325875
# 2                          39.935845
# 3                          38.095180
# 4                          36.340821
# ..                               ...
# 56                         47.749401
# 57                         47.670890
# 58                         48.509717
# 59                         49.859559
# 60                         49.266378
#
#     Taxes less subsidies on products (current US$)  \
# 0                                     2.035209e+09
# 1                                     2.303808e+09
# 2                                     2.674898e+09
# 3                                     3.294071e+09
# 4                                     3.758864e+09
# ..                                             ...
# 56                                    2.126772e+11
# 57                                    2.458117e+11
# 58                                    2.468067e+11
# 59                                    2.665373e+11
# 60                                    2.417314e+11
#
#     Total reserves (includes gold, current US$)  \
# 0                                  6.745366e+08
# 1                                  6.663571e+08
# 2                                  5.127918e+08
# 3                                  6.078625e+08
# 4                                  4.991451e+08
# ..                                          ...
# 56                                 3.616943e+11
# 57                                 4.126138e+11
# 58                                 3.991672e+11
# 59                                 4.634699e+11
# 60                                 5.902274e+11
#
#     Total reserves minus gold (current US$)  Trade (% of GDP)  \
# 0                              4.230000e+08         11.296833
# 1                              4.180000e+08         10.261163
# 2                              2.650000e+08         10.200790
# 3                              3.600000e+08         10.187338
# 4                              2.510000e+08          9.410549
# ..                                      ...               ...
# 56                             3.411452e+11         40.082486
# 57                             3.893501e+11         40.742497
# 58                             3.744252e+11         43.598657
# 59                             4.323784e+11         39.386771
# 60                             5.490869e+11         36.469883
#
#     Urban population  Urban population (% of total population)
# 0         80756165.0                                    17.924
# 1         82882675.0                                    18.032
# 2         85456483.0                                    18.218
# 3         88127852.0                                    18.405
# 4         90901311.0                                    18.595
# ..               ...                                       ...
# 56       439501314.0                                    33.182
# 57       449795398.0                                    33.600
# 58       460304169.0                                    34.030
# 59       471031529.0                                    34.472
# 60       481980332.0                                    34.926
#
# [61 rows x 68 columns]

# %%
plt.plot(df[c[0]],df[c[1]])
plt.title(c[1])
plt.figure(figsize=(20,20))

# %%
plt.plot(df[c[0]],df[c[2]])
plt.title(c[2])
plt.figure(figsize=(20,20))

# %%
plt.plot(df[c[0]],df[c[3]])
plt.title(c[3])
plt.figure(figsize=(20,20))

# %% [raw]
# After log_transform

# %%
log_new = df.iloc[:,1:]
log_new = np.log(1.0+log_new)
# Out:
# <ipython-input-15-36caefc77c15>:2: RuntimeWarning: invalid value encountered in log
#   log_new = np.log(1.0+log_new)

# %%
log_new
# Out:
#     Age dependency ratio (% of working-age population)  \
# 0                                            4.356697
# 1                                            4.369538
# 2                                            4.384368
# 3                                            4.398204
# 4                                            4.406706
# ..                                                ...
# 56                                           3.949090
# 57                                           3.937489
# 58                                           3.927407
# 59                                           3.916916
# 60                                           3.905293
#
#     Agriculture, forestry, and fishing, value added (% of GDP)  \
# 0                                            3.745091
# 1                                            3.722977
# 2                                            3.673038
# 3                                            3.696841
# 4                                            3.742130
# ..                                                ...
# 56                                           2.854388
# 57                                           2.865529
# 58                                           2.831456
# 59                                           2.872291
# 60                                           2.961088
#
#     Agriculture, forestry, and fishing, value added (current US$)  \
# 0                                           23.450994
# 1                                           23.486117
# 2                                           23.506913
# 3                                           23.669775
# 4                                           23.870128
# ..                                                ...
# 56                                          26.651567
# 57                                          26.807856
# 58                                          26.790236
# 59                                          26.894397
# 60                                          26.898102
#
#     Arms imports (SIPRI trend indicator values)  Broad money (% of GDP)  \
# 0                                     20.114460                3.138617
# 1                                     20.838379                3.113599
# 2                                     19.731713                3.132477
# 3                                     20.287857                3.096314
# 4                                     20.639884                3.035261
# ..                                          ...                     ...
# 56                                    21.822878                4.324785
# 57                                    21.791075                4.319409
# 58                                    21.118681                4.319455
# 59                                    21.846571                4.344402
# 60                                    21.752528                4.498432
#
#     Broad money to total reserves ratio  Changes in inventories (current US$)  \
# 0                              2.573892                             19.940535
# 1                              2.614431                                   NaN
# 2                              2.946086                             19.096655
# 3                              2.880383                                   NaN
# 4                              3.153238                                   NaN
# ..                                  ...                                   ...
# 56                             1.745687                             23.747941
# 57                             1.751725                             24.330393
# 58                             1.794668                             24.540551
# 59                             1.742204                             24.034752
# 60                             1.599321                             23.974145
#
#     Claims on central government, etc. (% GDP)  \
# 0                                     2.772593
# 1                                     2.755273
# 2                                     2.784185
# 3                                     2.749916
# 4                                     2.670585
# ..                                         ...
# 56                                    3.266698
# 57                                    3.186860
# 58                                    3.140160
# 59                                    3.208172
# 60                                    3.416699
#
#     Consumer price index (2010 = 100)  \
# 0                            1.260586
# 1                            1.272659
# 2                            1.298472
# 3                            1.319666
# 4                            1.413032
# ..                                ...
# 56                           5.051023
# 57                           5.083556
# 58                           5.122014
# 59                           5.158356
# 60                           5.222132
#
#     Domestic credit to private sector (% of GDP)  ...  Population, total  \
# 0                                       2.179641  ...          19.925974
# 1                                       2.252993  ...          19.945959
# 2                                       2.300631  ...          19.966278
# 3                                       2.313273  ...          19.986847
# 4                                       2.255157  ...          20.007562
# ..                                           ...  ...                ...
# 56                                      3.914045  ...          21.004314
# 57                                      3.907895  ...          21.014947
# 58                                      3.939094  ...          21.025326
# 59                                      3.934284  ...          21.035458
# 60                                      4.029822  ...          21.045353
#
#     Rural population  Rural population (% of total population)  \
# 0          19.728450                                  4.419756
# 1          19.747118                                  4.418455
# 2          19.765165                                  4.416211
# 3          19.783445                                  4.413949
# 4          19.801829                                  4.411646
# ..               ...                                       ...
# 56         20.601116                                  4.216828
# 57         20.605474                                  4.210645
# 58         20.609356                                  4.204245
# 59         20.612766                                  4.197623
# 60         20.615707                                  4.190775
#
#     Services, value added (% of GDP)  \
# 0                           3.683426
# 1                           3.671883
# 2                           3.712006
# 3                           3.665999
# 4                           3.620087
# ..                               ...
# 56                          3.886693
# 57                          3.885081
# 58                          3.902169
# 59                          3.929068
# 60                          3.917336
#
#     Taxes less subsidies on products (current US$)  \
# 0                                        21.433864
# 1                                        21.557829
# 2                                        21.707177
# 3                                        21.915390
# 4                                        22.047383
# ..                                             ...
# 56                                       26.083042
# 57                                       26.227832
# 58                                       26.231871
# 59                                       26.308780
# 60                                       26.211093
#
#     Total reserves (includes gold, current US$)  \
# 0                                     20.329537
# 1                                     20.317336
# 2                                     20.055381
# 3                                     20.225459
# 4                                     20.028407
# ..                                          ...
# 56                                    26.614065
# 57                                    26.745778
# 58                                    26.712646
# 59                                    26.862007
# 60                                    27.103774
#
#     Total reserves minus gold (current US$)  Trade (% of GDP)  \
# 0                                 19.862883          2.509342
# 1                                 19.850992          2.421360
# 2                                 19.395240          2.415984
# 3                                 19.701615          2.414783
# 4                                 19.340964          2.342820
# ..                                      ...               ...
# 56                                26.555574          3.715582
# 57                                26.687745          3.731520
# 58                                26.648658          3.797704
# 59                                26.792567          3.698502
# 60                                27.031522          3.623538
#
#     Urban population  Urban population (% of total population)
# 0          18.206945                                  2.940431
# 1          18.232937                                  2.946122
# 2          18.263518                                  2.955847
# 3          18.294299                                  2.965531
# 4          18.325285                                  2.975274
# ..               ...                                       ...
# 56         19.901151                                  3.531699
# 57         19.924303                                  3.543854
# 58         19.947398                                  3.556205
# 59         19.970436                                  3.568744
# 60         19.993414                                  3.581461
#
# [61 rows x 67 columns]

# %%
plt.plot(df[c[0]],log_new[c[1]])
plt.title(c[1])
plt.figure(figsize=(10,10))
plt.plot(df[c[0]],log_new[c[2]])
plt.title(c[2])
plt.figure(figsize=(10,10))
plt.plot(df[c[0]],log_new[c[3]])
plt.title(c[3])
plt.figure(figsize=(10,10))

# %% [raw]
# Quantile

# %%
quantile_data = df.iloc[:,1:].T
pt = QuantileTransformer(output_distribution='normal')
quantile_data = pt.fit_transform(quantile_data)
# Out:
# C:\Users\joani\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2367: UserWarning: n_quantiles (1000) is greater than the total number of samples (67). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "

# %%
plt.plot(df[c[0]],quantile_data[0])
plt.title(c[1])
plt.figure(figsize=(10,10))
plt.plot(df[c[0]],quantile_data[1])
plt.title(c[2])
plt.figure(figsize=(10,10))
plt.plot(df[c[0]],quantile_data[2])
plt.title(c[3])
plt.figure(figsize=(10,10))

# %% [raw]
# Yeo-Johnson
# Cant use box-cox due to negative values

# %%
yeo_data = df.iloc[:,1:].T
pt = PowerTransformer(method='yeo-johnson')
yeo_data = pt.fit_transform(yeo_data)

# %%
plt.plot(df[c[0]],quantile_data[0])
plt.title(c[1])
plt.figure(figsize=(10,10))
plt.plot(df[c[0]],quantile_data[1])
plt.title(c[2])
plt.figure(figsize=(10,10))
plt.plot(df[c[0]],quantile_data[2])
plt.title(c[3])
plt.figure(figsize=(10,10))

# %% [raw]
# QQ-plots for transformations

# %% [raw]
# Before transformation

# %%
sm.qqplot(df.iloc[:,1])
plt.show()
sm.qqplot(df.iloc[:,2])
plt.show()
sm.qqplot(df.iloc[:,3])
plt.show()

# %% [raw]
# After log-transform

# %%
sm.qqplot(log_new.iloc[:,1])
plt.show()
sm.qqplot(log_new.iloc[:,2])
plt.show()
sm.qqplot(log_new.iloc[:,3])
plt.show()

# %% [raw]
# After Quantile transform

# %%
sm.qqplot(quantile_data[1])
plt.show()
sm.qqplot(quantile_data[2])
plt.show()
sm.qqplot(quantile_data[3])
plt.show()

# %% [raw]
# After Yeo-Johnson Transform

# %%
sm.qqplot(yeo_data[1])
plt.show()
sm.qqplot(yeo_data[2])
plt.show()
sm.qqplot(yeo_data[3])
plt.show()

# %%
df.kurtosis()
# Out:
# Age dependency ratio (% of working-age population)              -1.044546
# Agriculture, forestry, and fishing, value added (% of GDP)      -1.355944
# Agriculture, forestry, and fishing, value added (current US$)    1.120919
# Arms imports (SIPRI trend indicator values)                      0.370350
# Broad money (% of GDP)                                          -1.232960
#                                                                    ...
# Total reserves (includes gold, current US$)                      1.189566
# Total reserves minus gold (current US$)                          1.130611
# Trade (% of GDP)                                                -0.766570
# Urban population                                                -1.051298
# Urban population (% of total population)                        -1.031869
# Length: 67, dtype: float64

# %%
df.skew()
# Out:
# Age dependency ratio (% of working-age population)              -0.547876
# Agriculture, forestry, and fishing, value added (% of GDP)       0.186145
# Agriculture, forestry, and fishing, value added (current US$)    1.487342
# Arms imports (SIPRI trend indicator values)                      0.864495
# Broad money (% of GDP)                                           0.352047
#                                                                    ...
# Total reserves (includes gold, current US$)                      1.504361
# Total reserves minus gold (current US$)                          1.491047
# Trade (% of GDP)                                                 0.817424
# Urban population                                                 0.405969
# Urban population (% of total population)                         0.139920
# Length: 67, dtype: float64

# %%
log_new.kurtosis()
# Out:
# Age dependency ratio (% of working-age population)              -0.817131
# Agriculture, forestry, and fishing, value added (% of GDP)      -1.423825
# Agriculture, forestry, and fishing, value added (current US$)   -0.861330
# Arms imports (SIPRI trend indicator values)                     -0.320127
# Broad money (% of GDP)                                          -1.304061
#                                                                    ...
# Total reserves (includes gold, current US$)                     -1.227802
# Total reserves minus gold (current US$)                         -1.310656
# Trade (% of GDP)                                                -1.294029
# Urban population                                                -1.203750
# Urban population (% of total population)                        -1.086810
# Length: 67, dtype: float64

# %%
log_new.skew()
# Out:
# Age dependency ratio (% of working-age population)              -0.706074
# Agriculture, forestry, and fishing, value added (% of GDP)      -0.108643
# Agriculture, forestry, and fishing, value added (current US$)    0.165360
# Arms imports (SIPRI trend indicator values)                     -0.270735
# Broad money (% of GDP)                                          -0.128781
#                                                                    ...
# Total reserves (includes gold, current US$)                      0.029557
# Total reserves minus gold (current US$)                          0.070340
# Trade (% of GDP)                                                 0.304663
# Urban population                                                -0.205169
# Urban population (% of total population)                        -0.118445
# Length: 67, dtype: float64

# %%
pd.DataFrame(quantile_data).kurtosis()
# Out:
# 0     6.007250
# 1     6.044451
# 2     6.027131
# 3     6.027131
# 4     6.027279
#         ...
# 56    6.026572
# 57    6.026572
# 58    6.026542
# 59    6.026542
# 60    6.026516
# Length: 61, dtype: float64

# %%
pd.DataFrame(quantile_data).skew()
# Out:
# 0     0.001744
# 1    -0.001754
# 2     0.000036
# 3     0.000036
# 4     0.000045
#         ...
# 56    0.000007
# 57    0.000007
# 58    0.000005
# 59    0.000005
# 60    0.000004
# Length: 61, dtype: float64

# %%
pd.DataFrame(yeo_data).kurtosis()
# Out:
# 0     8.394609
# 1     5.874961
# 2     7.896080
# 3     6.891853
# 4     7.893495
#         ...
# 56    5.168977
# 57    7.178635
# 58    7.428447
# 59    7.049049
# 60    7.312307
# Length: 61, dtype: float64

# %%
pd.DataFrame(yeo_data).kurtosis()
# Out:
# 0     8.394609
# 1     5.874961
# 2     7.896080
# 3     6.891853
# 4     7.893495
#         ...
# 56    5.168977
# 57    7.178635
# 58    7.428447
# 59    7.049049
# 60    7.312307
# Length: 61, dtype: float64

# %% [raw]
# Data Visualisation

# %%
#This is a dictionary containing some important features (Manually choosen) for which plots will be drawn.
select_col= ["GDP (current US$)",'Inflation, consumer prices (annual %)',"Agriculture, forestry, and fishing, value added (% of GDP)", "Broad money (% of GDP)","Domestic credit to private sector (% of GDP)", "Exports of goods and services (% of GDP)", "External balance on goods and services (% of GDP)","Manufacturing, value added (% of GDP)","Military expenditure (% of GDP)", "Services, value added (% of GDP)", "Trade (% of GDP)", "Urban population (% of total population)"]        
for i in select_col:
    x = df[c[0]]
    y = df[i]
    plt.scatter(x, y, label= "Datapoints", color= "purple",marker= "o", s=10)
    plt.xlabel('x - axis')
    plt.ylabel('y - axis')
    plt.title(i)
    plt.legend()
    plt.show()

# %%
for i in select_col:
    x = np.array(df[c[0]])
    y = np.array(df[i])
    plt.plot(x, np.transpose(y), color='black', linestyle='-', linewidth = 3,marker='o', markerfacecolor='yellow', markersize=4)
    plt.figure()
    plt.xlabel("X-axis data")
    plt.ylabel("Y-axis data")
    plt.title(i)
    plt.show()

# %%
red_circle = dict(markerfacecolor='red', marker='o')
mean_shape = dict(markerfacecolor='green', marker='D', markeredgecolor='green')

# %%
plt.title(select_col[0])
plt.boxplot(x=df[select_col[0]], vert=False, flierprops=red_circle, showmeans=True, meanprops=mean_shape)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f0dc7a2df0>,
#   <matplotlib.lines.Line2D at 0x1f0ddc24970>],
#  'caps': [<matplotlib.lines.Line2D at 0x1f0ddc24cd0>,
#   <matplotlib.lines.Line2D at 0x1f0ddc24850>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1f0df2c04f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f0ddc24d30>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f0ddcae220>],
#  'means': [<matplotlib.lines.Line2D at 0x1f0ddcaeeb0>]}

# %%
plt.title(select_col[1])
plt.boxplot(x=df[select_col[1]], vert=False, flierprops=red_circle, showmeans=True, meanprops=mean_shape,)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f0de0289d0>,
#   <matplotlib.lines.Line2D at 0x1f0de028c70>],
#  'caps': [<matplotlib.lines.Line2D at 0x1f0de0287f0>,
#   <matplotlib.lines.Line2D at 0x1f0de028f40>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1f0df2918e0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f0df9691f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f0df969100>],
#  'means': [<matplotlib.lines.Line2D at 0x1f0df9699d0>]}

# %%
plt.title(select_col[2])
plt.boxplot(x=df[select_col[2]], vert=False, flierprops=red_circle, showmeans=True, meanprops=mean_shape,)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f0ddc85880>,
#   <matplotlib.lines.Line2D at 0x1f0ddc858b0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1f0df975a60>,
#   <matplotlib.lines.Line2D at 0x1f0df975a30>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1f0ddc85400>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f0df975100>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f0de1bcd30>],
#  'means': [<matplotlib.lines.Line2D at 0x1f0df975040>]}

# %%
plt.title(select_col[2])
plt.boxplot(x=df[select_col[2]], vert=False, flierprops=red_circle, showmeans=True, meanprops=mean_shape,)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f0ddf4c910>,
#   <matplotlib.lines.Line2D at 0x1f0ddf4cfd0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1f0ddf4cc70>,
#   <matplotlib.lines.Line2D at 0x1f0ddf4c400>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1f0df2ebaf0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f0ddf4cb50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f0ddf24040>],
#  'means': [<matplotlib.lines.Line2D at 0x1f0ddf243d0>]}

# %%
plt.title(select_col[3])
plt.boxplot(x=df[select_col[3]], vert=False, flierprops=red_circle, showmeans=True, meanprops=mean_shape,)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f0df2d6160>,
#   <matplotlib.lines.Line2D at 0x1f0df2d6f70>],
#  'caps': [<matplotlib.lines.Line2D at 0x1f0df2d6cd0>,
#   <matplotlib.lines.Line2D at 0x1f0df2d6340>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1f0df324610>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f0df9acdf0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f0df9ac4f0>],
#  'means': [<matplotlib.lines.Line2D at 0x1f0df9ac0a0>]}

# %%
plt.title(select_col[4])
plt.boxplot(x=df[select_col[4]], vert=False, flierprops=red_circle, showmeans=True, meanprops=mean_shape,)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f0de0ca970>,
#   <matplotlib.lines.Line2D at 0x1f0de0ca7f0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1f0de0ca190>,
#   <matplotlib.lines.Line2D at 0x1f0de03f100>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1f0de0ca0a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f0de03f640>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f0df1ec790>],
#  'means': [<matplotlib.lines.Line2D at 0x1f0de03f760>]}

# %%
plt.title(select_col[8])
plt.boxplot(x=df[select_col[8]], vert=False, flierprops=red_circle, showmeans=True, meanprops=mean_shape,)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f0de1f2100>,
#   <matplotlib.lines.Line2D at 0x1f0de1f2070>],
#  'caps': [<matplotlib.lines.Line2D at 0x1f0de1f2a00>,
#   <matplotlib.lines.Line2D at 0x1f0df881af0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1f0de1f24f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f0df881c40>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f0df8810a0>],
#  'means': [<matplotlib.lines.Line2D at 0x1f0df881160>]}

# %% [raw]
# Correlation

# %%
df.corr()
# Out:
#                                                     Age dependency ratio (% of working-age population)  \
# Age dependency ratio (% of working-age population)                                           1.000000
# Agriculture, forestry, and fishing, value added...                                           0.940081
# Agriculture, forestry, and fishing, value added...                                          -0.928997
# Arms imports (SIPRI trend indicator values)                                                 -0.468926
# Broad money (% of GDP)                                                                      -0.980326
# ...                                                                                               ...
# Total reserves (includes gold, current US$)                                                 -0.906258
# Total reserves minus gold (current US$)                                                     -0.906007
# Trade (% of GDP)                                                                            -0.933595
# Urban population                                                                            -0.992534
# Urban population (% of total population)                                                    -0.975656
#
#                                                     Agriculture, forestry, and fishing, value added (% of GDP)  \
# Age dependency ratio (% of working-age population)                                           0.940081
# Agriculture, forestry, and fishing, value added...                                           1.000000
# Agriculture, forestry, and fishing, value added...                                          -0.785590
# Arms imports (SIPRI trend indicator values)                                                 -0.490146
# Broad money (% of GDP)                                                                      -0.966454
# ...                                                                                               ...
# Total reserves (includes gold, current US$)                                                 -0.743902
# Total reserves minus gold (current US$)                                                     -0.743166
# Trade (% of GDP)                                                                            -0.892706
# Urban population                                                                            -0.955876
# Urban population (% of total population)                                                    -0.968891
#
#                                                     Agriculture, forestry, and fishing, value added (current US$)  \
# Age dependency ratio (% of working-age population)                                          -0.928997
# Agriculture, forestry, and fishing, value added...                                          -0.785590
# Agriculture, forestry, and fishing, value added...                                           1.000000
# Arms imports (SIPRI trend indicator values)                                                  0.518804
# Broad money (% of GDP)                                                                       0.878551
# ...                                                                                               ...
# Total reserves (includes gold, current US$)                                                  0.975328
# Total reserves minus gold (current US$)                                                      0.973005
# Trade (% of GDP)                                                                             0.830047
# Urban population                                                                             0.919836
# Urban population (% of total population)                                                     0.892517
#
#                                                     Arms imports (SIPRI trend indicator values)  \
# Age dependency ratio (% of working-age population)                                    -0.468926
# Agriculture, forestry, and fishing, value added...                                    -0.490146
# Agriculture, forestry, and fishing, value added...                                     0.518804
# Arms imports (SIPRI trend indicator values)                                            1.000000
# Broad money (% of GDP)                                                                 0.519999
# ...                                                                                         ...
# Total reserves (includes gold, current US$)                                            0.466346
# Total reserves minus gold (current US$)                                                0.458424
# Trade (% of GDP)                                                                       0.448721
# Urban population                                                                       0.491748
# Urban population (% of total population)                                               0.518106
#
#                                                     Broad money (% of GDP)  \
# Age dependency ratio (% of working-age population)               -0.980326
# Agriculture, forestry, and fishing, value added...               -0.966454
# Agriculture, forestry, and fishing, value added...                0.878551
# Arms imports (SIPRI trend indicator values)                       0.519999
# Broad money (% of GDP)                                            1.000000
# ...                                                                    ...
# Total reserves (includes gold, current US$)                       0.867897
# Total reserves minus gold (current US$)                           0.866890
# Trade (% of GDP)                                                  0.945479
# Urban population                                                  0.981785
# Urban population (% of total population)                          0.975187
#
#                                                     Broad money to total reserves ratio  \
# Age dependency ratio (% of working-age population)                             0.715890
# Agriculture, forestry, and fishing, value added...                             0.725675
# Agriculture, forestry, and fishing, value added...                            -0.572054
# Arms imports (SIPRI trend indicator values)                                   -0.263286
# Broad money (% of GDP)                                                        -0.722992
# ...                                                                                 ...
# Total reserves (includes gold, current US$)                                   -0.575794
# Total reserves minus gold (current US$)                                       -0.576921
# Trade (% of GDP)                                                              -0.700328
# Urban population                                                              -0.703351
# Urban population (% of total population)                                      -0.716336
#
#                                                     Changes in inventories (current US$)  \
# Age dependency ratio (% of working-age population)                             -0.746468
# Agriculture, forestry, and fishing, value added...                             -0.674792
# Agriculture, forestry, and fishing, value added...                              0.736894
# Arms imports (SIPRI trend indicator values)                                     0.356006
# Broad money (% of GDP)                                                          0.753057
# ...                                                                                  ...
# Total reserves (includes gold, current US$)                                     0.781066
# Total reserves minus gold (current US$)                                         0.780797
# Trade (% of GDP)                                                                0.828060
# Urban population                                                                0.723947
# Urban population (% of total population)                                        0.692437
#
#                                                     Claims on central government, etc. (% GDP)  \
# Age dependency ratio (% of working-age population)                                   -0.751023
# Agriculture, forestry, and fishing, value added...                                   -0.818657
# Agriculture, forestry, and fishing, value added...                                    0.642384
# Arms imports (SIPRI trend indicator values)                                           0.550270
# Broad money (% of GDP)                                                                0.787462
# ...                                                                                        ...
# Total reserves (includes gold, current US$)                                           0.552288
# Total reserves minus gold (current US$)                                               0.545084
# Trade (% of GDP)                                                                      0.617184
# Urban population                                                                      0.788685
# Urban population (% of total population)                                              0.814862
#
#                                                     Consumer price index (2010 = 100)  \
# Age dependency ratio (% of working-age population)                          -0.961466
# Agriculture, forestry, and fishing, value added...                          -0.828152
# Agriculture, forestry, and fishing, value added...                           0.985851
# Arms imports (SIPRI trend indicator values)                                  0.470710
# Broad money (% of GDP)                                                       0.910042
# ...                                                                               ...
# Total reserves (includes gold, current US$)                                  0.963886
# Total reserves minus gold (current US$)                                      0.963075
# Trade (% of GDP)                                                             0.863528
# Urban population                                                             0.949993
# Urban population (% of total population)                                     0.918702
#
#                                                     Domestic credit to private sector (% of GDP)  \
# Age dependency ratio (% of working-age population)                                     -0.966714
# Agriculture, forestry, and fishing, value added...                                     -0.936184
# Agriculture, forestry, and fishing, value added...                                      0.910417
# Arms imports (SIPRI trend indicator values)                                             0.593214
# Broad money (% of GDP)                                                                  0.982747
# ...                                                                                          ...
# Total reserves (includes gold, current US$)                                             0.899675
# Total reserves minus gold (current US$)                                                 0.898033
# Trade (% of GDP)                                                                        0.943727
# Urban population                                                                        0.967430
# Urban population (% of total population)                                                0.962279
#
#                                                     ...  Population, total  \
# Age dependency ratio (% of working-age population)  ...          -0.979253
# Agriculture, forestry, and fishing, value added...  ...          -0.977175
# Agriculture, forestry, and fishing, value added...  ...           0.871656
# Arms imports (SIPRI trend indicator values)         ...           0.485220
# Broad money (% of GDP)                              ...           0.981342
# ...                                                 ...                ...
# Total reserves (includes gold, current US$)         ...           0.830070
# Total reserves minus gold (current US$)             ...           0.828979
# Trade (% of GDP)                                    ...           0.909285
# Urban population                                    ...           0.993508
# Urban population (% of total population)            ...           0.995214
#
#                                                     Rural population  \
# Age dependency ratio (% of working-age population)         -0.962542
# Agriculture, forestry, and fishing, value added...         -0.984508
# Agriculture, forestry, and fishing, value added...          0.831516
# Arms imports (SIPRI trend indicator values)                 0.476976
# Broad money (% of GDP)                                      0.973535
# ...                                                              ...
# Total reserves (includes gold, current US$)                 0.785751
# Total reserves minus gold (current US$)                     0.784612
# Trade (% of GDP)                                            0.898542
# Urban population                                            0.981404
# Urban population (% of total population)                    0.989070
#
#                                                     Rural population (% of total population)  \
# Age dependency ratio (% of working-age population)                                  0.975656
# Agriculture, forestry, and fishing, value added...                                  0.968891
# Agriculture, forestry, and fishing, value added...                                 -0.892517
# Arms imports (SIPRI trend indicator values)                                        -0.518106
# Broad money (% of GDP)                                                             -0.975187
# ...                                                                                      ...
# Total reserves (includes gold, current US$)                                        -0.844305
# Total reserves minus gold (current US$)                                            -0.842464
# Trade (% of GDP)                                                                   -0.888239
# Urban population                                                                   -0.993112
# Urban population (% of total population)                                           -1.000000
#
#                                                     Services, value added (% of GDP)  \
# Age dependency ratio (% of working-age population)                         -0.941342
# Agriculture, forestry, and fishing, value added...                         -0.848879
# Agriculture, forestry, and fishing, value added...                          0.875585
# Arms imports (SIPRI trend indicator values)                                 0.362342
# Broad money (% of GDP)                                                      0.913024
# ...                                                                              ...
# Total reserves (includes gold, current US$)                                 0.885741
# Total reserves minus gold (current US$)                                     0.887939
# Trade (% of GDP)                                                            0.895194
# Urban population                                                            0.912472
# Urban population (% of total population)                                    0.865916
#
#                                                     Taxes less subsidies on products (current US$)  \
# Age dependency ratio (% of working-age population)                                       -0.900555
# Agriculture, forestry, and fishing, value added...                                       -0.744067
# Agriculture, forestry, and fishing, value added...                                        0.989910
# Arms imports (SIPRI trend indicator values)                                               0.479251
# Broad money (% of GDP)                                                                    0.832052
# ...                                                                                            ...
# Total reserves (includes gold, current US$)                                               0.962128
# Total reserves minus gold (current US$)                                                   0.961232
# Trade (% of GDP)                                                                          0.776736
# Urban population                                                                          0.889175
# Urban population (% of total population)                                                  0.858767
#
#                                                     Total reserves (includes gold, current US$)  \
# Age dependency ratio (% of working-age population)                                    -0.906258
# Agriculture, forestry, and fishing, value added...                                    -0.743902
# Agriculture, forestry, and fishing, value added...                                     0.975328
# Arms imports (SIPRI trend indicator values)                                            0.466346
# Broad money (% of GDP)                                                                 0.867897
# ...                                                                                         ...
# Total reserves (includes gold, current US$)                                            1.000000
# Total reserves minus gold (current US$)                                                0.999770
# Trade (% of GDP)                                                                       0.843467
# Urban population                                                                       0.884721
# Urban population (% of total population)                                               0.844305
#
#                                                     Total reserves minus gold (current US$)  \
# Age dependency ratio (% of working-age population)                                -0.906007
# Agriculture, forestry, and fishing, value added...                                -0.743166
# Agriculture, forestry, and fishing, value added...                                 0.973005
# Arms imports (SIPRI trend indicator values)                                        0.458424
# Broad money (% of GDP)                                                             0.866890
# ...                                                                                     ...
# Total reserves (includes gold, current US$)                                        0.999770
# Total reserves minus gold (current US$)                                            1.000000
# Trade (% of GDP)                                                                   0.843453
# Urban population                                                                   0.883711
# Urban population (% of total population)                                           0.842464
#
#                                                     Trade (% of GDP)  \
# Age dependency ratio (% of working-age population)         -0.933595
# Agriculture, forestry, and fishing, value added...         -0.892706
# Agriculture, forestry, and fishing, value added...          0.830047
# Arms imports (SIPRI trend indicator values)                 0.448721
# Broad money (% of GDP)                                      0.945479
# ...                                                              ...
# Total reserves (includes gold, current US$)                 0.843467
# Total reserves minus gold (current US$)                     0.843453
# Trade (% of GDP)                                            1.000000
# Urban population                                            0.914746
# Urban population (% of total population)                    0.888239
#
#                                                     Urban population  \
# Age dependency ratio (% of working-age population)         -0.992534
# Agriculture, forestry, and fishing, value added...         -0.955876
# Agriculture, forestry, and fishing, value added...          0.919836
# Arms imports (SIPRI trend indicator values)                 0.491748
# Broad money (% of GDP)                                      0.981785
# ...                                                              ...
# Total reserves (includes gold, current US$)                 0.884721
# Total reserves minus gold (current US$)                     0.883711
# Trade (% of GDP)                                            0.914746
# Urban population                                            1.000000
# Urban population (% of total population)                    0.993112
#
#                                                     Urban population (% of total population)
# Age dependency ratio (% of working-age population)                                 -0.975656
# Agriculture, forestry, and fishing, value added...                                 -0.968891
# Agriculture, forestry, and fishing, value added...                                  0.892517
# Arms imports (SIPRI trend indicator values)                                         0.518106
# Broad money (% of GDP)                                                              0.975187
# ...                                                                                      ...
# Total reserves (includes gold, current US$)                                         0.844305
# Total reserves minus gold (current US$)                                             0.842464
# Trade (% of GDP)                                                                    0.888239
# Urban population                                                                    0.993112
# Urban population (% of total population)                                            1.000000
#
# [67 rows x 67 columns]

# %%
sns.heatmap(df.corr().iloc[:10,:10],annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df.corr().iloc[20:30,20:30],annot=True)
# Out:
# <AxesSubplot:>

# %% [raw]
# PCA

# %%
X = np.array(df.iloc[:,1:63]).T

# %%
X
# Out:
# array([[7.69990446e+01, 7.80071064e+01, 7.91875306e+01, ...,
#         4.97751669e+01, 4.92452418e+01, 4.86646203e+01],
#        [4.13128391e+01, 4.03874016e+01, 3.83713352e+01, ...,
#         1.59701575e+01, 1.66774624e+01, 1.83189877e+01],
#        [1.52980963e+10, 1.58449614e+10, 1.61779235e+10, ...,
#         4.31371805e+11, 4.78727241e+11, 4.80504068e+11],
#        ...,
#        [8.20760000e+01, 8.19680000e+01, 8.17820000e+01, ...,
#         6.59700000e+01, 6.55280000e+01, 6.50740000e+01],
#        [3.87824618e+01, 3.83258752e+01, 3.99358450e+01, ...,
#         4.85097166e+01, 4.98595589e+01, 4.92663781e+01],
#        [2.03520873e+09, 2.30380816e+09, 2.67489811e+09, ...,
#         2.46806721e+11, 2.66537320e+11, 2.41731435e+11]])

# %% [raw]
# We can do PCA for only 61 features since we have only 61 rows in our dataset

# %%
pca = PCA(n_components=61,svd_solver='full')

# %%
pca.fit_transform(X)
# Out:
# array([[-1.00789814e+12, -1.97682280e+10, -6.18433013e+08, ...,
#         -1.04316328e-05,  1.31050005e-05,  4.00465724e-05],
#        [-1.00789814e+12, -1.97682279e+10, -6.18433140e+08, ...,
#         -6.90216000e-06,  1.41865959e-05,  2.06191246e-05],
#        [ 3.88561890e+11, -1.20497612e+11,  5.39086190e+10, ...,
#         -6.81778493e-06,  1.41973009e-05,  2.10327218e-05],
#        ...,
#        [-1.00789814e+12, -1.97682280e+10, -6.18433002e+08, ...,
#         -6.76039990e-06,  1.27978077e-05,  1.91803658e-05],
#        [-1.00789814e+12, -1.97682279e+10, -6.18433106e+08, ...,
#         -6.80382295e-06,  1.41739114e-05,  2.07210014e-05],
#        [-3.15094409e+11, -8.04149425e+10, -2.51931016e+10, ...,
#         -6.73029719e-06,  1.41433897e-05,  2.06468404e-05]])

# %%
print(pca.explained_variance_ratio_)
# Out:
# [9.97419214e-01 2.05042086e-03 2.57376993e-04 1.40015106e-04
#  5.11984749e-05 3.57939998e-05 1.43235703e-05 1.41701478e-05
#  6.95503152e-06 4.41507273e-06 2.17295462e-06 1.90720636e-06
#  1.35096502e-06 3.01096044e-07 2.81678513e-07 5.73407208e-08
#  4.00245802e-08 5.93533471e-09 1.14065682e-11 1.37874659e-12
#  2.68861743e-13 3.73900424e-15 2.15237267e-18 5.79875244e-24
#  2.70232970e-24 1.29434903e-24 6.61389932e-25 5.51419936e-25
#  3.82234650e-25 2.23967617e-25 1.54989649e-25 1.15224144e-25
#  6.77575451e-26 3.41436132e-26 2.31954097e-26 1.73461921e-26
#  1.45419774e-26 9.10903000e-27 8.43681092e-27 5.90907031e-27
#  4.55370450e-27 3.44600919e-27 1.49596222e-27 9.77523195e-28
#  7.37073320e-28 5.64100719e-28 3.37892703e-28 2.67857425e-29
#  2.41546344e-30 1.66873339e-31 5.09149274e-32 1.24011588e-32
#  9.21037227e-33 9.21037227e-33 9.21037227e-33 9.21037227e-33
#  9.21037227e-33 9.21037227e-33 9.21037227e-33 9.21037227e-33
#  1.08600124e-33]

# %%
print(pca.singular_values_)
# Out:
# [1.69118605e+13 7.66785740e+11 2.71667310e+11 2.00373354e+11
#  1.21166073e+11 1.01311241e+11 6.40882132e+10 6.37440585e+10
#  4.46582883e+10 3.55812706e+10 2.49619121e+10 2.33857534e+10
#  1.96822423e+10 9.29191110e+09 8.98730294e+09 4.05493685e+09
#  3.38778557e+09 1.30459326e+09 5.71913071e+07 1.98835876e+07
#  8.78045510e+06 1.03545326e+06 2.48434128e+04 4.07774258e+01
#  2.78369525e+01 1.92654085e+01 1.37715021e+01 1.25745877e+01
#  1.04692977e+01 8.01392246e+00 6.66659189e+00 5.74809936e+00
#  4.40789614e+00 3.12901223e+00 2.57901308e+00 2.23025539e+00
#  2.04204004e+00 1.61617576e+00 1.55539851e+00 1.30170358e+00
#  1.14270715e+00 9.94055740e-01 6.54957070e-01 5.29439156e-01
#  4.59735316e-01 4.02189611e-01 3.11273342e-01 8.76404030e-02
#  2.63179923e-02 6.91744954e-03 3.82098283e-03 1.88574800e-03
#  1.62514125e-03 1.62514125e-03 1.62514125e-03 1.62514125e-03
#  1.62514125e-03 1.62514125e-03 1.62514125e-03 1.62514125e-03
#  5.58043023e-04]

# %% [raw]
# Hypothesis Testing

# %% [markdown]
# Claim has been made that Military expenditure is correlated to GDP by greater than or equal to 0.5

# %%
test= ['GDP per capita (current US$)','Military expenditure (current USD)']

# %%
df[test].corr()
# Out:
#                                     GDP per capita (current US$)  \
# GDP per capita (current US$)                            1.000000
# Military expenditure (current USD)                      0.996706
#
#                                     Military expenditure (current USD)
# GDP per capita (current US$)                                  0.996706
# Military expenditure (current USD)                            1.000000

# %%
r = 0.997
r0 = 0.5
t = (r-r0)/np.sqrt( (1-np.square(r)) / (df.shape[0]-2) )

# %%
t
# Out:
# 49.3210978118634

# %%
pval = scipy.stats.norm.sf(t)
print(float(pval))
if pval<0.05:
    print("reject null hypothesis")
else:
    print("accept null hypothesis")
# Out:
# 0.0
# reject null hypothesis

# %% [raw]
# Chi-Square Test

# %%
plt.plot(df['GDP per capita (current US$)'],df['Industry (including construction), value added (current US$)'])

# %%
def chi_square(atr1,atr2):
    data_crosstab = pd.crosstab(df[atr1],df[atr2],margins=True, margins_name="Total")
    x = 0
    rows = df[atr1].unique()
    columns = df[atr2].unique()
    for i in columns:
        for j in rows:
            O = data_crosstab[i][j]
            E = data_crosstab[i]['Total'] * data_crosstab['Total'][j] / data_crosstab['Total']['Total']
            x += ((O-E)**2) /E
    print(x)
    return x

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Age dependency ratio (% of working-age population)',
#        'Agriculture, forestry, and fishing, value added (% of GDP)',
#        'Agriculture, forestry, and fishing, value added (current US$)',
#        'Arms imports (SIPRI trend indicator values)', 'Broad money (% of GDP)',
#        'Broad money to total reserves ratio',
#        'Changes in inventories (current US$)',
#        'Claims on central government, etc. (% GDP)',
#        'Consumer price index (2010 = 100)',
#        'Domestic credit to private sector (% of GDP)',
#        'Domestic credit to private sector by banks (% of GDP)',
#        'Exports of goods and services (% of GDP)',
#        'Exports of goods and services (current US$)',
#        'External balance on goods and services (% of GDP)',
#        'External balance on goods and services (current US$)',
#        'Final consumption expenditure (% of GDP)',
#        'Final consumption expenditure (current US$)',
#        'Fixed telephone subscriptions',
#        'Fixed telephone subscriptions (per 100 people)', 'GDP (current US$)',
#        'GDP deflator (base year varies by country)',
#        'GDP per capita (current US$)',
#        'General government final consumption expenditure (% of GDP)',
#        'General government final consumption expenditure (current US$)',
#        'GNI (current US$)', 'Gross capital formation (% of GDP)',
#        'Gross capital formation (current US$)',
#        'Gross domestic savings (% of GDP)',
#        'Gross domestic savings (current US$)',
#        'Gross fixed capital formation (% of GDP)',
#        'Gross fixed capital formation (current US$)',
#        'Gross national expenditure (% of GDP)',
#        'Gross national expenditure (current US$)',
#        'Gross national expenditure deflator (base year varies by country)',
#        'Gross value added at basic prices (GVA) (current US$)',
#        'Households and NPISHs final consumption expenditure (% of GDP)',
#        'Households and NPISHs Final consumption expenditure (current US$)',
#        'Imports of goods and services (% of GDP)',
#        'Imports of goods and services (current US$)',
#        'Industry (including construction), value added (% of GDP)',
#        'Industry (including construction), value added (current US$)',
#        'Inflation, consumer prices (annual %)',
#        'Manufacturing, value added (% of GDP)',
#        'Manufacturing, value added (current US$)',
#        'Merchandise exports (current US$)',
#        'Merchandise imports (current US$)', 'Merchandise trade (% of GDP)',
#        'Military expenditure (% of GDP)', 'Military expenditure (current USD)',
#        'Monetary Sector credit to private sector (% GDP)',
#        'Net primary income (Net income from abroad) (current US$)',
#        'Population ages 0-14, total',
#        'Population ages 15-64 (% of total population)', 'Population, female',
#        'Population, female (% of total population)', 'Population, male',
#        'Population, male (% of total population)', 'Population, total',
#        'Rural population', 'Rural population (% of total population)',
#        'Services, value added (% of GDP)',
#        'Taxes less subsidies on products (current US$)',
#        'Total reserves (includes gold, current US$)',
#        'Total reserves minus gold (current US$)', 'Trade (% of GDP)',
#        'Urban population', 'Urban population (% of total population)'],
#       dtype='object')

# %%
x = chi_square('Gross national expenditure (current US$)','Industry (including construction), value added (current US$)')
p = 1 - scipy.stats.norm.cdf(x, 3600)
print(p)
if x<=0.05:
    print("Dependent")
else:
    print("Indipendent")
# Out:
# 3659.9999999997367
# 0.0
# Indipendent

# %%
df[['GDP per capita (current US$)','Industry (including construction), value added (current US$)']].corr()
# Out:
#                                                     GDP per capita (current US$)  \
# GDP per capita (current US$)                                            1.000000
# Industry (including construction), value added ...                      0.996362
#
#                                                     Industry (including construction), value added (current US$)
# GDP per capita (current US$)                                                                 0.996362
# Industry (including construction), value added ...                                           1.000000

# %% [raw]
# 2007-2009 Fiancial Crash as a Case Study

# %%
new = df.iloc[47:50]

# %%
new
# Out:
#        Unnamed: 0  Age dependency ratio (% of working-age population)  \
# 47  2007 [YR2007]                                          58.472050
# 48  2008 [YR2008]                                          57.705703
# 49  2009 [YR2009]                                          56.882514
#
#     Agriculture, forestry, and fishing, value added (% of GDP)  \
# 47                                          16.750120
# 48                                          16.790942
# 49                                          16.744270
#
#     Agriculture, forestry, and fishing, value added (current US$)  \
# 47                                       2.038046e+11
# 48                                       2.013059e+11
# 49                                       2.246891e+11
#
#     Arms imports (SIPRI trend indicator values)  Broad money (% of GDP)  \
# 47                                 2.275000e+09               72.280424
# 48                                 1.858000e+09               77.372956
# 49                                 1.863000e+09               79.075196
#
#     Broad money to total reserves ratio  Changes in inventories (current US$)  \
# 47                             3.179795                          6.078493e+10
# 48                             3.603493                          2.145105e+10
# 49                             3.727303                          5.752057e+10
#
#     Claims on central government, etc. (% GDP)  \
# 47                                   16.220406
# 48                                   19.485752
# 49                                   23.155964
#
#     Consumer price index (2010 = 100)  ...  Population, total  \
# 47                          74.324964  ...       1.183209e+09
# 48                          80.530554  ...       1.200670e+09
# 49                          89.294173  ...       1.217726e+09
#
#     Rural population  Rural population (% of total population)  \
# 47       829358847.0                                    70.094
# 48       837515186.0                                    69.754
# 49       845260299.0                                    69.413
#
#     Services, value added (% of GDP)  \
# 47                         44.008158
# 48                         45.882550
# 49                         45.984883
#
#     Taxes less subsidies on products (current US$)  \
# 47                                    1.014573e+11
# 48                                    7.420910e+10
# 49                                    8.251898e+10
#
#     Total reserves (includes gold, current US$)  \
# 47                                 2.765781e+11
# 48                                 2.574227e+11
# 49                                 2.846829e+11
#
#     Total reserves minus gold (current US$)  Trade (% of GDP)  \
# 47                             2.669883e+11         45.686269
# 48                             2.474189e+11         53.368220
# 49                             2.651817e+11         46.272870
#
#     Urban population  Urban population (% of total population)
# 47       353850624.0                                    29.906
# 48       363154576.0                                    30.246
# 49       372465918.0                                    30.587
#
# [3 rows x 68 columns]

# %%
for i in new.columns[1:]:
    plt.title(i)
    x = new[new.columns[0]]
    y = new[i]
    plt.plot(x, y)
    plt.show()
